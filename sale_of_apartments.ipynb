# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#'total_area'" data-toc-modified-id="'total_area'-4.0.1"><span class="toc-item-num">4.0.1&nbsp;&nbsp;</span>'total_area'</a></span></li><li><span><a href="#'last_price'" data-toc-modified-id="'last_price'-4.0.2"><span class="toc-item-num">4.0.2&nbsp;&nbsp;</span>'last_price'</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-4.0.3"><span class="toc-item-num">4.0.3&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#'ceiling_height'" data-toc-modified-id="'ceiling_height'-4.0.4"><span class="toc-item-num">4.0.4&nbsp;&nbsp;</span>'ceiling_height'</a></span></li><li><span><a href="#'days_exposition'" data-toc-modified-id="'days_exposition'-4.0.5"><span class="toc-item-num">4.0.5&nbsp;&nbsp;</span>'days_exposition'</a></span></li></ul></li><li><span><a href="#Изучим,-какие-факторы-больше-всего-влияют-на-стоимость-квартиры" data-toc-modified-id="Изучим,-какие-факторы-больше-всего-влияют-на-стоимость-квартиры-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучим, какие факторы больше всего влияют на стоимость квартиры</a></span><ul class="toc-item"><li><span><a href="#Вляние-количество-комнат-на-цену" data-toc-modified-id="Вляние-количество-комнат-на-цену-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Вляние количество комнат на цену</a></span></li><li><span><a href="#Влияние-расстояние-до-центра-на-цену" data-toc-modified-id="Влияние-расстояние-до-центра-на-цену-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Влияние расстояние до центра на цену</a></span></li><li><span><a href="#Влияние-этажа-на-цену" data-toc-modified-id="Влияние-этажа-на-цену-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Влияние этажа на цену</a></span></li><li><span><a href="#Взаимосвязь-стоимости-и-времени-размещения-объявления" data-toc-modified-id="Взаимосвязь-стоимости-и-времени-размещения-объявления-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Взаимосвязь стоимости и времени размещения объявления</a></span></li></ul></li><li><span><a href="#Выберем-10-населенных-пунктов-с-наибольшим-числом-объявлений.-Посчитем-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделим-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья." data-toc-modified-id="Выберем-10-населенных-пунктов-с-наибольшим-числом-объявлений.-Посчитем-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделим-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Выберем 10 населенных пунктов с наибольшим числом объявлений. Посчитем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья.</a></span></li><li><span><a href="#Вы-делим-объявления-из-Санкт-Петербурга-и-выясним-какая-область-входит-в-центр.-Расстояние-до-центра-будет-выражено-в-км.-Посмотрим-среднюю-цену-для-каждого-км-и-построим-график-который-наглядно-покажет-изменения-цены-в-зависимости-с-удалением-от-центра." data-toc-modified-id="Вы-делим-объявления-из-Санкт-Петербурга-и-выясним-какая-область-входит-в-центр.-Расстояние-до-центра-будет-выражено-в-км.-Посмотрим-среднюю-цену-для-каждого-км-и-построим-график-который-наглядно-покажет-изменения-цены-в-зависимости-с-удалением-от-центра.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Вы делим объявления из Санкт-Петербурга и выясним какая область входит в центр. Расстояние до центра будет выражено в км. Посмотрим среднюю цену для каждого км и построим график который наглядно покажет изменения цены в зависимости с удалением от центра.</a></span><ul class="toc-item"><li><span><a href="#Общая-площадь" data-toc-modified-id="Общая-площадь-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Общая площадь</a></span></li><li><span><a href="#Цена" data-toc-modified-id="Цена-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Цена</a></span></li><li><span><a href="#Количество-комнат" data-toc-modified-id="Количество-комнат-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Количество комнат</a></span></li><li><span><a href="#Высота-потолков" data-toc-modified-id="Высота-потолков-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Высота потолков</a></span></li></ul></li><li><span><a href="#Проанализируем-факторы-влияющие-на-цену-недвижимости-и-сравним-нашу-выборку-с-общей-базой-данных." data-toc-modified-id="Проанализируем-факторы-влияющие-на-цену-недвижимости-и-сравним-нашу-выборку-с-общей-базой-данных.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Проанализируем факторы влияющие на цену недвижимости и сравним нашу выборку с общей базой данных.</a></span></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#После-проделанной-работы-можно-сделать-выводы:" data-toc-modified-id="После-проделанной-работы-можно-сделать-выводы:-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>После проделанной работы можно сделать выводы:</a></span></li></ul></li></ul></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекc Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ## Изучение данных из файла

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t') # читаем датасет по указанному адресу, добавлям параметр разделителя 
display(df) # Выводим общий вид таблицы
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2                10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3                 0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4                 2  10000000.0      100.00  2018-06-19T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
df.isna().mean().apply('{:.0%}'.format) # Смотрими на долю пропусков в каждой колонке, умножаю для удобства.
# Out:
# total_images             0%
# last_price               0%
# total_area               0%
# first_day_exposition     0%
# rooms                    0%
# ceiling_height          39%
# floors_total             0%
# living_area              8%
# floor                    0%
# is_apartment            88%
# studio                   0%
# open_plan                0%
# kitchen_area            10%
# balcony                 49%
# locality_name            0%
# airports_nearest        23%
# cityCenters_nearest     23%
# parks_around3000        23%
# parks_nearest           66%
# ponds_around3000        23%
# ponds_nearest           62%
# days_exposition         13%
# dtype: object

# %% [markdown]
# <a name="0."></a> Описание данных:
#
# * <b>airports_nearest</b> — расстояние до ближайшего аэропорта в метрах (м)
# * <b>balcony</b> — число балконов
# * <b>ceiling_height</b> — высота потолков (м)
# * <b>cityCenters_nearest</b> — расстояние до центра города (м)
# * <b>days_exposition</b> — сколько дней было размещено объявление (от публикации до снятия)
# * <b>first_day_exposition</b> — дата публикации
# * <b>floor</b> — этаж
# * <b>floors_total</b> — всего этажей в доме
# * <b>is_apartment</b> — апартаменты (булев тип)
# * <b>kitchen_area</b> — площадь кухни в квадратных метрах (м²)
# * <b>last_price</b> — цена на момент снятия с публикации
# * <b>living_area</b> — жилая площадь в квадратных метрах(м²)
# * <b>locality_name</b> — название населённого пункта
# * <b>open_plan</b> — свободная планировка (булев тип)
# * <b>parks_around3000</b> — число парков в радиусе 3 км
# * <b>parks_nearest</b> — расстояние до ближайшего парка (м)
# * <b>ponds_around3000</b> — число водоёмов в радиусе 3 км
# * <b>ponds_nearest</b> — расстояние до ближайшего водоёма (м)
# * <b>rooms</b> — число комнат
# * <b>studio</b> — квартира-студия (булев тип)
# * <b>total_area</b> — площадь квартиры в квадратных метрах (м²)
# * <b>total_images</b> — число фотографий квартиры в объявлении

# %%
try_df = df

# %% [markdown]
# ### Вывод

# %% [markdown]
# Ознакомились с данными и изучили их структуру. Видим, что в данных много пропущенных значений, займёмся их обработкой.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Пропуски найдены в следующих столбцах

# %% [markdown]
# * ceiling_height
# * floors_total
# * living_area
# * is_apartment
# * kitchen_area
# * balcony
# * locality_name
# * airports_nearest
# * cityCenters_nearest
# * parks_around3000
# * parks_nearest
# * ponds_around3000
# * ponds_nearest
# * days_exposition

# %% [markdown]
# Предпологаю что в столбце balcony пропуск это отсутсиве значений и в колонках с собранными автоматическими данными аналогичный случай заменю пропуски на 0

# %%
df['balcony'] = df['balcony'].fillna(0).astype(int)
df['parks_around3000'] = df['parks_around3000'].fillna(0).astype(int)
df['ponds_around3000'] = df['ponds_around3000'].fillna(0).astype(int)

# %% [markdown]
# Так как заполнить 'floors_total', 'locality_name' столбцы не представлятся воможныи из-за нехватки данных в таблице и их пропуски могут повляить на результаты я удалю пропуски в этих столбцах

# %%
df.dropna(subset = ['floors_total', 'locality_name'], inplace = True)

# %% [markdown]
# Пропуски в столбцах airports_nearest, cityCenters_nearest, parks_nearest и ponds_nearest заменим на нетипичные значения в дальнейшем эти данные будут выделяться.

# %%
df['airports_nearest'] = df['airports_nearest'].fillna(-1)
df['cityCenters_nearest'] = df['cityCenters_nearest'].fillna(-1)
df['parks_nearest'] = df['parks_nearest'].fillna(-1)
df['ponds_nearest'] = df['ponds_nearest'].fillna(-1)
df['days_exposition'] = df['days_exposition'].fillna(-1).astype(int)

# %% [markdown]
# Мы бы могли обработать пропуски в расстоянии до центра cityCenters_nearest сгруппировав объявления по названию населенного пункта locality_name, а затем высчитав медиану, однако такой способ не сработает - для некоторых населенных пунктов, не дано расстояние до центра города, так как центра, скорее всего, нет. Поэтому, если мы будем пытаться заменить нетипичные значения (-1) на медиану или среднее, то результатом все равно окажется -1. В этом случае отсутсвие информации - это информация.
#
# Пропуски в столбце days_exposition можно попробовать обработать с помощью столбца locality_name.

# %%
def fill_days_exposition(row):
    days_exposition = row['days_exposition']
    locality_name = row['locality_name']
    if days_exposition == -1:      
        return locality_name_to_median[locality_name]
    return days_exposition
 
locality_name_to_median = df.groupby('locality_name')['days_exposition'].median().to_dict()   
       
df['days_exposition'] = df.apply(fill_days_exposition, axis=1)

# %%
df.query('days_exposition == -1')['days_exposition'].count()
# Out:
# 100

# %%
df.loc[df['days_exposition'] == -1] = df['days_exposition'].median()
df.query('days_exposition == -1')['days_exposition'].count()
# Out:
# 0

# %% [markdown]
# Избавлюсь в таблице от столбцов которые не будут использоваться в иследовании.

# %%
df.drop(['is_apartment'], axis='columns', inplace=True)
df.drop(['total_images'], axis='columns', inplace=True)
df.drop(['studio'], axis='columns', inplace=True)
df.drop(['open_plan'], axis='columns', inplace=True)

# %% [markdown]
# Для заполнения пропусков в колонке living_area, считаю нужным для начало определить медианный коэффициент по извсетным данным, коэффициент я считаю как отношение жилой площади к общей и беру медиану по всем рассчем.

# %%
t = df['living_area'] / df['total_area']
t.median()
# Out:
# 0.5689655172413793

# %% [markdown]
# Заполним пропуски и приведем сразу к нужному типу

# %%
df['living_area'] = df['living_area'].fillna(value=(df['total_area']*0.56).astype(int))

# %% [markdown]
# Для того что бы заполнить пропуски  в столбце kitchen_area так как их доля пропусков не так велика позволю себе из общей площади вычесть жилую и заполню медианной.

# %%
kitchen_area = df['total_area'] - df['living_area']
print(kitchen_area.median())
#df['kitchen_area'] = df['kitchen_area'].fillna(kitchen_area.median())
# Out:
# 22.0

# %%
groups = df.groupby(['total_area', 'living_area', 'rooms'])['kitchen_area'].transform('median')
df['kitchen_area'] = df['kitchen_area'].fillna(groups)
df['kitchen_area'].median()
# Out:
# 9.1

# %% [markdown]
# Заполнить пропуски в ceiling_height средним или медианной не получиться это приведет к искажению, поищем столбец с которым у него сильная корреляция.

# %%
df['ceiling_height'].corr(df['cityCenters_nearest']) # Смотрим по расстоняию до центра города.
# Out:
# -0.10391167304888728

# %%
df['ceiling_height'].corr(df['last_price']) # Смотрим по цене.
# Out:
# -0.03785231525353869

# %%
df['ceiling_height'].corr(df['total_area']) # по общей площадию
# Out:
# 0.05615564473536557

# %%
df['ceiling_height'].corr(df['rooms']) # Смотрим по количеству комнат. Кореляция очень высокая это нам полходит.
# Out:
# 0.9681643630469601

# %%
df['ceiling_height'] = df['ceiling_height'].fillna(-1)

# %%
def count_ceiling_height(row):
    ceiling_height = row['ceiling_height']
    rooms = row['rooms']
    if ceiling_height == -1:      
        return rooms_to_median[rooms]
    return ceiling_height
 
rooms_to_median = df.groupby('rooms').median()['ceiling_height'].to_dict()    
       
df['ceiling_height'] = df.apply(count_ceiling_height, axis=1)

# %% [markdown]
# Приведем столбец first_day_exposition к типу данных datetime.

# %%
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y%m%dT%H:%M:%S')

# %% [markdown]
# Изменим типы данных в некоторых столбцах.

# %%
int_column = ['last_price', 'rooms', 'floors_total', 'floor', 'balcony', 'airports_nearest', 
              'cityCenters_nearest', 'parks_around3000', 'ponds_nearest', 'ponds_around3000', 
              'ponds_nearest', 'days_exposition'] # Пеереведем столбцы в стип int, я считаю нам не к чему такая точность. 
#
for i in int_column:
    df[i] = df[df[i].notnull()][i].astype('int')

# %%
round_to_1 = ['total_area', 'ceiling_height',
                   'living_area', 'kitchen_area'] # Округлим до 1 знака так как это метраж недвижимости
for i in round_to_1:
    df[i] = df[df[i].notnull()][i].round(1)

# %%
df.info()# Финальная проверка и можно переходить к добавлению данных.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 18 columns):
# last_price              23565 non-null int64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null datetime64[ns]
# rooms                   23565 non-null int64
# ceiling_height          23565 non-null float64
# floors_total            23565 non-null int64
# living_area             23565 non-null float64
# floor                   23565 non-null int64
# kitchen_area            22450 non-null float64
# balcony                 23565 non-null int64
# locality_name           23565 non-null object
# airports_nearest        23565 non-null int64
# cityCenters_nearest     23565 non-null int64
# parks_around3000        23565 non-null int64
# parks_nearest           23565 non-null float64
# ponds_around3000        23565 non-null int64
# ponds_nearest           23565 non-null int64
# days_exposition         23565 non-null int64
# ...

# %%
df.isna().mean()
# Out:
# last_price              0.000000
# total_area              0.000000
# first_day_exposition    0.000000
# rooms                   0.000000
# ceiling_height          0.000000
# floors_total            0.000000
# living_area             0.000000
# floor                   0.000000
# kitchen_area            0.047316
# balcony                 0.000000
# locality_name           0.000000
# airports_nearest        0.000000
# cityCenters_nearest     0.000000
# parks_around3000        0.000000
# parks_nearest           0.000000
# ponds_around3000        0.000000
# ponds_nearest           0.000000
# days_exposition         0.000000
# dtype: float64

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %% [markdown]
# Посчитаем цену квадратного метра

# %%
df['price_m2'] = (df['last_price']/df['total_area']).astype('int')

# %% [markdown]
# Напишем функцию для определния этажа

# %%
floors_total = df['floors_total']

def find_floor(row):
    floor = row['floor']
    if floor == 1:
        return('первый')
    elif floor == row['floors_total']:
        return('последний')
    return('другой')

df['floor_type'] = df.apply(find_floor, axis=1)

# %% [markdown]
# Добавим еще 3 столбца - день недели (exposition_weekday), где понедельник под номером 0, а воскресенье - 6; месяц (exposition_month); и год публикации объявления (exposition_year).

# %%
df['exposition_weekday'] = df['first_day_exposition'].dt.weekday
df['exposition_month'] = df['first_day_exposition'].dt.month
df['exposition_year'] = df['first_day_exposition'].dt.year

# %% [markdown]
# Проверим таблицу на дуликаты

# %%
df.duplicated().sum()
# Out:
# 99

# %%
df = df.drop_duplicates().reset_index(drop=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.head(15) # Выведем общий вид обновленной таблицы.
# Out:
#     last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 0     13000000       108.0           2019-03-07      3             2.7
# 1      3350000        40.4           2018-12-04      1             2.5
# 2      5196000        56.0           2015-08-20      2             2.5
# 3     64900000       159.0           2015-07-24      3             2.5
# 4     10000000       100.0           2018-06-19      2             3.0
# 5      2890000        30.4           2018-09-10      1             2.5
# 6      3700000        37.3           2017-11-02      1             2.5
# 7      7915000        71.6           2019-04-18      2             2.5
# 8      2900000        33.2           2018-05-23      1             2.5
# 9      5400000        61.0           2017-02-26      3             2.5
# 10     5050000        39.6           2017-11-16      1             2.7
# 11     3300000        44.0           2018-08-27      2             2.5
# ...

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# Изучим параметры параметры: площадь, цена, число комнат, высота потолков и построем для них гистограммы и диаграммы размаха

# %%
def craft_hist(column, xmin, xmax, l):
    df[column].hist(bins=70, range=(xmin, xmax), figsize=(16,9))
    plt.title(column, fontsize=15)
    plt.xlabel(l, fontsize=15)
    plt.ylabel('Count', fontsize=15)# Автоматизируем построение диаграммы 
    
    
def craft_boxplot(column, lab, ymin=0, ymax=200):  # # Автоматизируем построение диаграммы
    plt.ylim(ymin, ymax) 
    df[column].plot( kind='box', grid=True, figsize=(12,8))
    plt.ylabel(lab, fontsize=15)

# %%
df['total_area'].plot(kind='box', figsize=(12,8));

# %% [markdown]
# #### 'total_area'

# %%
craft_hist('total_area', 0, 600, 'Метр2')

# %%
craft_boxplot('total_area','Метр2');

# %% [markdown]
# Гистограмма выглядит правдопадобно, большенство квартир от 15 до 110м2

# %%
df = df.query('total_area>=15 and total_area<=110')

# %% [markdown]
# #### 'last_price'

# %%
craft_hist('last_price', 0, 20000000, 'Цена')

# %%
craft_boxplot('last_price','Цена', -600000, 20000000)

# %% [markdown]
# Пик варируеться от 3млн до 3,5 млн. Полсе 8млн количество кв значительно падает. Нормальная цена находится в интервале от 0 до 11млн. так же на гистограмме видно что около 0 есть какие-то значение посмотрим на него, возможно это выбивающиеся данные от которых тоже стоит избавиться.

# %%
df.query('last_price<100000')
# Out:
#       last_price  total_area          first_day_exposition  rooms  \
# 101           79        79.0 1970-01-01 00:00:00.000000079     79
# 8717       12190       109.0 2019-03-20 00:00:00.000000000      2
#
#       ceiling_height  floors_total  living_area  floor  kitchen_area  balcony  \
# 101             79.0            79         79.0     79          79.0       79
# 8717             2.8            25         32.0     25          40.5        0
#
#       ... parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 101   ...               79           79.0                79             79
# 8717  ...                1          805.0                 0             -1
#
#       days_exposition  price_m2  floor_type  exposition_weekday  \
# 101                79         1   последний                   3
# 8717                8       111   последний                   2
#
#       exposition_month exposition_year
# 101                  1            1970
# ...

# %% [markdown]
# Избавимся от первой строчи так так по параметрам видно что это не настоящая\ошибочная запись

# %%
df = df.query('last_price> 10000 and last_price<=11000000')

# %% [markdown]
# #### rooms

# %%
craft_hist('rooms', -1,  10, 'Количество комнат')

# %% [markdown]
# Большентво от 1 - 3 комнат, есть небольшое количество 0 - это студии.

# %%
craft_boxplot('rooms', 'Количество комнат', -1, 10)

# %% [markdown]
# Нормальные значения находятся от 0 до 6. Все остальное уберем.

# %%
df = df.query('rooms>0 and rooms<=6')

# %% [markdown]
# #### 'ceiling_height'

# %%
craft_hist('ceiling_height', 1, 10, 'Высотра потолков')

# %% [markdown]
# Гистограмма показывает что данные в порядке, значений 4х метровыми потолками уже не так много. Посмотрим на что лежит за пределами усов

# %%
craft_boxplot('ceiling_height', 'Высота потолков', 0, 6)

# %% [markdown]
# Нормальные значания лежат в пределах 2,1 - 3х метров. Уберем все лишнее.

# %%
df=df.query('ceiling_height>=2.1 and ceiling_height<=3')

# %% [markdown]
# #### 'days_exposition'

# %%
craft_hist('days_exposition', -1, 2000, 'Количесво дней')

# %% [markdown]
# Ожидаемое распределение, редко недвижимость продается дольше года.

# %%
craft_boxplot('days_exposition','Количесво дней', -20, 500)

# %% [markdown]
# Нормальные значения лежат в пределе 410 дней но есть и значения близкие к 0 посмотрим на них на сколько они правдападобны.

# %%
df.query('days_exposition < 2') # Оно всего одно и выглядит на мой взгляд, довольно правдиво, оставим его.
# Out:
#       last_price  total_area first_day_exposition  rooms  ceiling_height  \
# 1620     4000000        49.9           2019-05-01      2             2.5
#
#       floors_total  living_area  floor  kitchen_area  balcony  ...  \
# 1620             9         25.0      1          10.0        0  ...
#
#      parks_around3000  parks_nearest  ponds_around3000  ponds_nearest  \
# 1620                1           20.0                 1            681
#
#       days_exposition  price_m2  floor_type  exposition_weekday  \
# 1620                1     80160      первый                   2
#
#       exposition_month exposition_year
# 1620                 5            2019
#
# [1 rows x 23 columns]

# %%
df = df.query('days_exposition >= 1 and days_exposition <= 410')

# %%
df['days_exposition'].describe()
# Out:
# count    18052.000000
# mean       105.163306
# std         93.286157
# min          1.000000
# 25%         43.000000
# 50%         74.000000
# 75%        142.000000
# max        410.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Можно считать что нормальной продаже является 74 дней, если продажи заняли от 142 дней  это можно считать что продажа затянулась, а если сделка состоялась до 43 дней это считаеться быстрой продажей.

# %%
craft_hist('days_exposition', 0, 150, 'Количесво дней')

# %%
print('Из первоначальной базы данных понадобилась убрать {:.0%} данных'.format((len(try_df) - len(df))/len(try_df)))
# Out:
# Из первоначальной базы данных понадобилась убрать 23% данных

# %% [markdown]
# ### Изучим, какие факторы больше всего влияют на стоимость квартиры

# %%
def craft_plot(data, y, x):
    data.plot(y=y, x=x, kind='scatter', alpha=0.5, figsize=(16,9))

# %%
index=df.index
price_rooms = df.pivot_table(index=index, values=['total_area','rooms', 'price_m2'], aggfunc='mean')

# %% [markdown]
# #### Вляние количество комнат на цену

# %%
craft_plot(price_rooms, 'price_m2', 'rooms')

# %%
craft_plot(price_rooms, 'price_m2', 'total_area')

# %% [markdown]
# Из графиков видно что цена за м2 слабо зависит от количества комнат и общей площади, даже на оборот при увеличении числа комнат и площади цена начинает падать.

# %% [markdown]
# #### Влияние расстояние до центра на цену

# %% [markdown]
# Посмотрим на зависимость цены от расстояния до центра.

# %%
distance_to_centre = df.query('cityCenters_nearest != -1')
distance_to_centre['price_m2'].corr(distance_to_centre['cityCenters_nearest'])
# Out:
# -0.3938748459894396

# %%
craft_plot(distance_to_centre, 'price_m2', 'cityCenters_nearest')

# %% [markdown]
# Становиться видно что с увелечением дистанции от центра цена на м2 падает, логичный показатель.

# %% [markdown]
# #### Влияние этажа на цену

# %% [markdown]
# Посмотрим на зависимость стоимость и этажа.

# %%
floor_price = df.loc[:, ['floor_type', 'price_m2']]

floor_price_corr = floor_price.floor_type.str.get_dummies(sep=' ').corrwith(floor_price.price_m2)
floor_price_corr
# Out:
# другой       0.231135
# первый      -0.176668
# последний   -0.125446
# dtype: float64

# %% [markdown]
# Кореляция на первом и последним этаже отрицательная, это означает что на них недвижимость стоит дешевле чем на других этажах.

# %% [markdown]
# Визуализируем корреляцию

# %%
fig, ax = plt.subplots(figsize=(13,13))
sns.heatmap(df.corr(),  square=True, vmin=-1, vmax=1, center=0, ax=ax, annot=True);

# %% [markdown]
# Видно что 'price_m2' корелирует с 'last_price' (очевидно так как на его основе был рассчитан параметр 'price_m2'), также корелирует с выстой потолков, жилой площадью, этажем, площадью кухни, количеством комнат, общей площадью и инфраструкторой во круг недвижимости(аэропорт, парки, озера)

# %% [markdown]
# #### Взаимосвязь стоимости и времени размещения объявления

# %% [markdown]
# Посмотрим на взаимосвязь стоимости и времени размещения объявления: дня недели, месяца и года.

# %%
corr_price_date = df.pivot_table(index=index, values=['exposition_weekday', 'exposition_month', 'exposition_year', 'price_m2'], aggfunc='median')
corr_price_date.corr()
# Out:
#                     exposition_month  exposition_weekday  exposition_year  \
# exposition_month            1.000000            0.011373        -0.308145
# exposition_weekday          0.011373            1.000000        -0.011345
# exposition_year            -0.308145           -0.011345         1.000000
# price_m2                   -0.005808           -0.009324         0.094268
#
#                     price_m2
# exposition_month   -0.005808
# exposition_weekday -0.009324
# exposition_year     0.094268
# price_m2            1.000000

# %% [markdown]
# Видно что цена не коррелирует с годом, месяцем и неделей публикации, но связь может быть не линейной.

# %%
pd.plotting.scatter_matrix(corr_price_date, figsize=(13,13), alpha=0.02);

# %% [markdown]
# Приходим к выводам:
# * Квартиры дешевеют к маю и дорожают к зиме.
# * Самая дешевая цена за м2 в выходные, причем суббота сильно дешевле чем в воскресенье.
# * Наглядна видна тенденция дорожания м2 с каждым годом, однако 2018 год выделяется особенно.

# %% [markdown]
# ### Выберем 10 населенных пунктов с наибольшим числом объявлений. Посчитем среднюю цену квадратного метра в этих населённых пунктах. Выделим населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
local_price_m2 = df.loc[:,['locality_name', 'price_m2']]
local_price_m2 = local_price_m2.pivot_table(index='locality_name', values='price_m2', aggfunc=['count', 'mean'])
local_price_m2.columns = ['count', 'price_m2']
top_local = local_price_m2.sort_values(by='count', ascending=False).head(10)
top_local.plot(y='count', kind='pie', figsize=(10,10));

# %%
top_local.sort_values(by='price_m2', ascending=False)
# Out:
#                    count       price_m2
# locality_name
# Санкт-Петербург    11328  104943.539548
# Пушкин               289   99890.878893
# деревня Кудрово      246   92423.020325
# посёлок Парголово    294   89980.520408
# посёлок Мурино       452   85312.907080
# посёлок Шушары       393   78360.587786
# Колпино              302   75183.758278
# Гатчина              264   68877.776515
# Всеволожск           337   67266.910979
# Выборг               194   58008.231959

# %% [markdown]
# Самые дорогие квартиры в Санкт-Петербурге и Пушкине, из топа самый дешевой локацией оказался Выборг

# %% [markdown]
# ### Вы делим объявления из Санкт-Петербурга и выясним какая область входит в центр. Расстояние до центра будет выражено в км. Посмотрим среднюю цену для каждого км и построим график который наглядно покажет изменения цены в зависимости с удалением от центра.

# %%
spb_local = df.query('locality_name == "Санкт-Петербург"')
spb_local = spb_local.query('cityCenters_nearest != -1')
spb_local_price = spb_local.loc[:,['locality_name', 'cityCenters_nearest','last_price']]
# Приводим метры в км и округлим
spb_local['cityCenters_nearest'] = (spb_local['cityCenters_nearest']/1000).astype(int)
#Приводим цену в млн
spb_local['last_price'] = (spb_local['last_price']/1000000).astype(int)
spb_local_pivot = spb_local.pivot_table(index='cityCenters_nearest', values='last_price', aggfunc=('mean'))
spb_local_pivot.plot(y='last_price', kind='bar', figsize=(16,9));

# %% [markdown]
# На пятом км стоимость сильно падает, значит возьмем с 0 до 5 км включительно за центр.

# %% [markdown]
# Вы делим сегмент недвижимости в центре.

# %%
spb_local_center = spb_local.query('cityCenters_nearest != -1')
spb_local_center['cityCenters_nearest'] = (spb_local_center['cityCenters_nearest']).round().astype(int)
#spb_local_center = spb_local_center.query('cityCenters_nearest < 3')
spb_local_center = spb_local_center.query('cityCenters_nearest < 6')

# %% [markdown]
# Проанализируем для этой таблицы такие параметры как площадь, цена, число комнат, высота потолков.

# %%
def craft_hist_spb(i, xmin=0, xmax=7):
    spb_local_center[i].hist(bins=50, range=(xmin,xmax), figsize=(16,9))

# %% [markdown]
# #### Общая площадь

# %%
craft_hist_spb('total_area', xmax=120)

# %% [markdown]
# #### Цена

# %%
craft_hist_spb('last_price',xmax=12 )

# %% [markdown]
# #### Количество комнат

# %%
craft_hist_spb('rooms')

# %% [markdown]
# #### Высота потолков

# %%
craft_hist_spb('ceiling_height', xmin=2.2, xmax=3.5)

# %% [markdown]
# Можно сделать следующие выводы что большее количество недвижимости в центре Питера имеют следующие параметры.
# * Площадь 40м2 и 60м2
# * Ценой 6млн
# * 2х комнатных
# * С метражем 2.5м

# %% [markdown]
# ### Проанализируем факторы влияющие на цену недвижимости и сравним нашу выборку с общей базой данных.

# %%
def craft_plot(data, data2, y, x):
    data.plot(y=y, x=x, kind='scatter', alpha=0.2)
    data2.plot(y=y, x=x, kind='scatter', alpha=0.5)

# %%
spb_local_center['price_m2'].corr(spb_local_center['rooms'])
# Out:
# -0.5266289837923929

# %%
craft_plot(spb_local_center, df, 'price_m2', 'rooms')

# %% [markdown]
# C увеличением числа комнат цена падает.

# %% [markdown]
# Проверим кореляцию с типом этажей.

# %%
spb_local_center_type = spb_local_center.loc[:,['floor_type', 'price_m2']]

spb_local_center_type = spb_local_center_type.floor_type.str.get_dummies(sep=' ').corrwith(spb_local_center_type.price_m2)
spb_local_center_type
# Out:
# другой       0.160278
# первый      -0.150199
# последний   -0.052261
# dtype: float64

# %% [markdown]
# Взаимосвязь таккая же как и в общей базе данных.

# %%
spb_local_center['price_m2'].corr(spb_local_center['cityCenters_nearest'])
# Out:
# 0.09811710250753

# %%
craft_plot(spb_local_center, df, 'price_m2', 'cityCenters_nearest')

# %% [markdown]
# Видно что на 5м км цены больше остальных

# %%
index1 = spb_local_center.index
exposition_date_spb = spb_local_center.pivot_table(index=index1, values=['exposition_weekday', 'exposition_month', 'exposition_year', 'price_m2'], aggfunc='median')

# %%
pd.plotting.scatter_matrix(exposition_date_spb, figsize=(13,13));

# %% [markdown]
# Сделаем выводы о цене недвижимости в разные промежутки времяни.
# * Самая низкая цена на недвижимость приходится на январь и август, в остальное время цена почти одинаковая.
# * Так же как и общем анализе дешевле всего м2 в выходные.
# * И рост цен от года к к году так же сказался на ценах недвижимости в центре города

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# Изучили архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет, что впоследствии поможет определять рыночную стоимость объектов недвижимости.
#
# * заполнили пропущенные данные в исследуемых столбцах
# * установили параметры (площадь, цена, число комнат, высота потолков и др.)
# * установили связь между разными параметрами и построили графики
# * избавились от редких и выбивающихся значений
# * ответили на поставленные вопросы

# %% [markdown]
# #### После проделанной работы можно сделать выводы:
# * Самый дорогой ценник за м2 в Санкт-Питербурге и Пушкине
# * Квартиры на крайних этажах дешевле чем на других
# * Чем дальше от центра тем цена меньше, но сам центр Питера это не касается так как там цена одинаковая
# * Что число комнат отрицательно сказывается на цене.
# * Ценик в Питере больше всех почти в 2 раза
# * Обнаружилась следующая свзяь между временем размещения и стоимостью: недвижимость дорожала от года к году однако в 2018 были самые высокие цены, объявления которые публиковались в выходные имели самую низкую цену и стала видна циклиное изменеие цен от начало года к середине цена падает и осенью снова выростает
